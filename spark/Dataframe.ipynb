# %%
data=[(1,'Naval'),(2,'Raj')]
schema="id int, name string"

# %% [markdown]
# Creating a spark dataframe 1

# %%
df = spark.createDataFrame(data,schema)

# %%
display(df)

# %% [markdown]
# ###Adding additional comments in the development branch - Prasanth
